# %% [markdown]
# # 1. Import Data

# %%
import pandas as pd

file_url = 'https://raw.githubusercontent.com/ajayt0m/Telecom_Dashboard_ConnectX/main/A-1_NO_OF_VILLAGES_TOWNS_HOUSEHOLDS_POPULATION_AND_AREA.xlsx'

census_df = pd.read_excel(file_url)

# %%
census_df
# Out:
#        State  Code District Code  \
# 0              NaN           NaN
# 1              1.0             2
# 2              0.0           000
# 3              0.0           000
# 4              0.0           000
# ...            ...           ...
# 20017          NaN           NaN
# 20018          NaN          (ii)
# 20019          NaN             5
# 20020          NaN           NaN
# 20021          NaN          NA -
#
#                                        Sub District Code  \
# 0                                                    NaN
# 1                                                      3
# 2                                                  00000
# 3                                                  00000
# 4                                                  00000
# ...                                                  ...
# 20017  The same has also been done while working out ...
# 20018  Rural and Urban population of Arunachal Prades...
# ...

# %% [markdown]
# # 2. Cleaning Header

# %%
census_df.head()
# Out:
#    State  Code District Code Sub District Code  \
# 0          NaN           NaN               NaN
# 1          1.0             2                 3
# 2          0.0           000             00000
# 3          0.0           000             00000
# 4          0.0           000             00000
#
#   India/ State/ Union Territory/ District/ Sub-district      Name  \
# 0                                                NaN          NaN
# 1                                                  4            5
# 2                                              INDIA     INDIA @&
# 3                                              INDIA      INDIA $
# 4                                              INDIA      INDIA $
#
#   Total/\nRural/\nUrban Number of villages   Unnamed: 7  Number of towns  \
# 0                   NaN          Inhabited  Uninhabited              NaN
# 1                     6                  7            8              9.0
# ...

# %%
for col in census_df.columns:
    print(col)
# Out:
# State  Code
# District Code
# Sub District Code
# India/ State/ Union Territory/ District/ Sub-district
# Name
# Total/
# Rural/
# Urban
# Number of villages
# Unnamed: 7
# Number of towns
# Number of households
# Population
# Unnamed: 11
# Unnamed: 12
# Area
#  (In sq. km)
# Population per sq. km.

# %%
#Rename 'India/ State/ Union Territory/ District/ Sub-district' to 'Geographic Subdivision'
census_df.rename(columns = {'India/ State/ Union Territory/ District/ Sub-district':'Geographic Subdivision'}, inplace = True)

#Rename 'Total/\nRural/\nUrban' to 'Total/Rural/Urban'
census_df.rename(columns = {'Total/\nRural/\nUrban':'Total/Rural/Urban'}, inplace = True)

#Rename 'Number of villages' to 'NV_Inhabited'
census_df.rename(columns = {'Number of villages':'NV_Inhabited'}, inplace = True)

#Rename 'Unnamed: 7' to 'NV_Uninhabited'
census_df.rename(columns = {'Unnamed: 7':'NV_Uninhabited'}, inplace = True)

#Rename 'Population' to 'P_Total'
census_df.rename(columns = {'Population':'P_Total'}, inplace = True)

#Rename 'Unnamed: 11' to 'P_Males'
census_df.rename(columns = {'Unnamed: 11':'P_Males'}, inplace = True)

#Rename 'Unnamed: 12' to 'P_Females'
census_df.rename(columns = {'Unnamed: 12':'P_Females'}, inplace = True)

#Rename 'Area\n (In sq. km)' to 'Area(sq.km)'
census_df.rename(columns = {'Area\n (In sq. km)':'Area(sq.km)'}, inplace = True)

# %%
census_df.head()
# Out:
#    State  Code District Code Sub District Code Geographic Subdivision  \
# 0          NaN           NaN               NaN                    NaN
# 1          1.0             2                 3                      4
# 2          0.0           000             00000                  INDIA
# 3          0.0           000             00000                  INDIA
# 4          0.0           000             00000                  INDIA
#
#        Name Total/Rural/Urban NV_Inhabited NV_Uninhabited  Number of towns  \
# 0       NaN               NaN    Inhabited    Uninhabited              NaN
# 1         5                 6            7              8              9.0
# 2  INDIA @&             Total       597608          43324           7933.0
# 3   INDIA $             Rural       597608          43324              0.0
# 4   INDIA $             Urban            0              0           7933.0
#
#    Number of households     P_Total    P_Males  P_Females  Area(sq.km)  \
# ...

# %%
for col in census_df.columns:
    print(col)
# Out:
# State  Code
# District Code
# Sub District Code
# Geographic Subdivision
# Name
# Total/Rural/Urban
# NV_Inhabited
# NV_Uninhabited
# Number of towns
# Number of households
# P_Total
# P_Males
# P_Females
# Area(sq.km)
# Population per sq. km.

# %% [markdown]
# # 3. Delete first 2 rows - Useless values

# %%
census_df_hc = census_df.iloc[2:, :]

# %%
census_df_hc.head()
# Out:
#    State  Code District Code Sub District Code Geographic Subdivision  \
# 2          0.0           000             00000                  INDIA
# 3          0.0           000             00000                  INDIA
# 4          0.0           000             00000                  INDIA
# 5          1.0           000             00000                  STATE
# 6          1.0           000             00000                  STATE
#
#                  Name Total/Rural/Urban NV_Inhabited NV_Uninhabited  \
# 2            INDIA @&             Total       597608          43324
# 3             INDIA $             Rural       597608          43324
# 4             INDIA $             Urban            0              0
# 5  JAMMU & KASHMIR @&             Total         6337            216
# 6     JAMMU & KASHMIR             Rural         6337            216
#
#    Number of towns  Number of households     P_Total    P_Males  P_Females  \
# ...

# %% [markdown]
# # 4. Removing Junk values

# %%
import numpy as np

# %%
#making junk values in 'Distric Code' to nan
junk_values = ['@', '&', '$', '###', '#', '^', '*', '**', '##', '^^', 'Note:', '1', '2', '3', '4', '(ii)', '5', 'NA -']
census_df_hc['District Code'] = census_df_hc['District Code'].replace(junk_values, np.nan)
# Out:
# C:\Users\imaja\AppData\Local\Temp\ipykernel_32900\4066742404.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   census_df_hc['District Code'] = census_df_hc['District Code'].replace(junk_values, np.nan)

# %%
#making junk values in 'Geographic Subdivision' to nan
junk_values = ['total',7687.39, 10137.61]
census_df_hc['Geographic Subdivision'] = census_df_hc['Geographic Subdivision'].replace(junk_values, np.nan)
# Out:
# C:\Users\imaja\AppData\Local\Temp\ipykernel_32900\3372078924.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   census_df_hc['Geographic Subdivision'] = census_df_hc['Geographic Subdivision'].replace(junk_values, np.nan)

# %%
#making junk values in 'Total/Rural/Urban' to nan
junk_values = [106.16, 309.35]
census_df_hc['Total/Rural/Urban'] = census_df_hc['Total/Rural/Urban'].replace(junk_values, np.nan)
# Out:
# C:\Users\imaja\AppData\Local\Temp\ipykernel_32900\2944810799.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   census_df_hc['Total/Rural/Urban'] = census_df_hc['Total/Rural/Urban'].replace(junk_values, np.nan)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 5. Missing Values

# %%
plot_missing = census_df_hc.isna().sum().plot(kind="bar")
plot_missing.set_xlabel("Columns", fontsize=12)
plot_missing.set_ylabel("Count of missing values", fontsize=12)
plot_missing.set_title("Missing Values per Column", fontsize=14)
plot_missing.set_xticklabels(census_df_hc.columns, rotation=45, ha="right")
plt.show()

# %%
#Rows with nan for more than 8 columns would be dropped
#28 rows dropped
census_df_hc = census_df_hc.dropna(thresh=census_df_hc.shape[1]-8)
census_df_hc
# Out:
#        State  Code District Code Sub District Code Geographic Subdivision  \
# 2              0.0           000             00000                  INDIA
# 3              0.0           000             00000                  INDIA
# 4              0.0           000             00000                  INDIA
# 5              1.0           000             00000                  STATE
# 6              1.0           000             00000                  STATE
# ...            ...           ...               ...                    ...
# 19989         35.0           640             05923           SUB-DISTRICT
# 19990         35.0           640             05923           SUB-DISTRICT
# 19991         35.0           640             05924           SUB-DISTRICT
# 19992         35.0           640             05924           SUB-DISTRICT
# 19993         35.0           640             05924           SUB-DISTRICT
#
#                      Name Total/Rural/Urban NV_Inhabited NV_Uninhabited  \
# ...

# %% [markdown]
# # 6. Imputation

# %%
#Need to impute 117 rows where the 2 column values are nan

census_clean = census_df_hc
census_clean['Area(sq.km)']=census_clean['Area(sq.km)'].fillna(census_clean['Area(sq.km)'].mean())
census_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19992 entries, 2 to 19993
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State  Code             19992 non-null  float64
#  1   District Code           19992 non-null  object
#  2   Sub District Code       19992 non-null  object
#  3   Geographic Subdivision  19992 non-null  object
#  4   Name                    19992 non-null  object
#  5   Total/Rural/Urban       19992 non-null  object
#  6   NV_Inhabited            19992 non-null  object
#  7   NV_Uninhabited          19992 non-null  object
#  8   Number of towns         19992 non-null  float64
#  9   Number of households    19992 non-null  float64
#  10  P_Total                 19992 non-null  object
#  11  P_Males                 19992 non-null  object
#  12  P_Females               19992 non-null  object
#  13  Area(sq.km)             19992 non-null  float64
# ...

# %%
census_clean['Population per sq. km.']=census_clean['Population per sq. km.'].fillna(census_clean['Population per sq. km.'].mean())
census_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19992 entries, 2 to 19993
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State  Code             19992 non-null  float64
#  1   District Code           19992 non-null  object
#  2   Sub District Code       19992 non-null  object
#  3   Geographic Subdivision  19992 non-null  object
#  4   Name                    19992 non-null  object
#  5   Total/Rural/Urban       19992 non-null  object
#  6   NV_Inhabited            19992 non-null  object
#  7   NV_Uninhabited          19992 non-null  object
#  8   Number of towns         19992 non-null  float64
#  9   Number of households    19992 non-null  float64
#  10  P_Total                 19992 non-null  object
#  11  P_Males                 19992 non-null  object
#  12  P_Females               19992 non-null  object
#  13  Area(sq.km)             19992 non-null  float64
# ...

# %% [markdown]
# ### Checking for any row with atleast one null value

# %%
census_clean[census_clean.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [State  Code, District Code, Sub District Code, Geographic Subdivision, Name, Total/Rural/Urban, NV_Inhabited, NV_Uninhabited, Number of towns, Number of households, P_Total, P_Males, P_Females, Area(sq.km), Population per sq. km.]
# Index: []

# %%
plot_missing = census_clean.isna().sum().plot(kind="bar")
plot_missing.set_xlabel("Columns", fontsize=12)
plot_missing.set_ylabel("Count of missing values", fontsize=12)
plot_missing.set_title("Missing Values per Column", fontsize=14)
plot_missing.set_xticklabels(census_clean.columns, rotation=45, ha="right")
plt.show()

# %% [markdown]
# # 7. Further cleaning - Junk Values

# %%
census_clean.head()
# Out:
#    State  Code District Code Sub District Code Geographic Subdivision  \
# 2          0.0           000             00000                  INDIA
# 3          0.0           000             00000                  INDIA
# 4          0.0           000             00000                  INDIA
# 5          1.0           000             00000                  STATE
# 6          1.0           000             00000                  STATE
#
#                  Name Total/Rural/Urban NV_Inhabited NV_Uninhabited  \
# 2            INDIA @&             Total       597608          43324
# 3             INDIA $             Rural       597608          43324
# 4             INDIA $             Urban            0              0
# 5  JAMMU & KASHMIR @&             Total         6337            216
# 6     JAMMU & KASHMIR             Rural         6337            216
#
#    Number of towns  Number of households     P_Total    P_Males  P_Females  \
# ...

# %% [markdown]
# ### Need to change 'JAMMU & KASHMIR @&' to 'JAMMU & KASHMIR'
# ### Need to change 'INDIA @&', 'INDIA $' to 'INDIA

# %%
census_clean['Name'] = census_clean['Name'].str.replace('@&', '')
census_clean['Name'] = census_clean['Name'].str.replace('$', '')
# Out:
# C:\Users\imaja\AppData\Local\Temp\ipykernel_32900\723704892.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   census_clean['Name'] = census_clean['Name'].str.replace('$', '')

# %%
census_clean['Name'] = census_clean['Name'].str.replace('INDIA ', 'INDIA')
census_clean['Name'] = census_clean['Name'].str.replace('JAMMU & KASHMIR ', 'JAMMU & KASHMIR')

# %%
census_clean.head()
# Out:
#    State  Code District Code Sub District Code Geographic Subdivision  \
# 2          0.0           000             00000                  INDIA
# 3          0.0           000             00000                  INDIA
# 4          0.0           000             00000                  INDIA
# 5          1.0           000             00000                  STATE
# 6          1.0           000             00000                  STATE
#
#               Name Total/Rural/Urban NV_Inhabited NV_Uninhabited  \
# 2            INDIA             Total       597608          43324
# 3            INDIA             Rural       597608          43324
# 4            INDIA             Urban            0              0
# 5  JAMMU & KASHMIR             Total         6337            216
# 6  JAMMU & KASHMIR             Rural         6337            216
#
#    Number of towns  Number of households     P_Total    P_Males  P_Females  \
# ...

# %% [markdown]
# # 8. Export the clean data

# %%
census_clean.reset_index(drop=True, inplace=True)

# %%
census_clean.head()
# Out:
#    State  Code District Code Sub District Code Geographic Subdivision  \
# 0          0.0           000             00000                  INDIA
# 1          0.0           000             00000                  INDIA
# 2          0.0           000             00000                  INDIA
# 3          1.0           000             00000                  STATE
# 4          1.0           000             00000                  STATE
#
#               Name Total/Rural/Urban NV_Inhabited NV_Uninhabited  \
# 0            INDIA             Total       597608          43324
# 1            INDIA             Rural       597608          43324
# 2            INDIA             Urban            0              0
# 3  JAMMU & KASHMIR             Total         6337            216
# 4  JAMMU & KASHMIR             Rural         6337            216
#
#    Number of towns  Number of households     P_Total    P_Males  P_Females  \
# ...

# %% [markdown]
# file_path = r"ajayt0m/Telecom_Dashboard_ConnectX/census_cleaned.csv"
#
# census_clean.to_csv(file_path, index=False)

# %%
import pandas as pd

file_path = r"D:\GitHub\Telecom_Dashboard_ConnectX\census_clean.csv"

census_clean.to_csv(file_path, index=False)

# %% [markdown]
# ### Export as .xlsx

# %%
file_path = r"D:\GitHub\Telecom_Dashboard_ConnectX\census_clean.xlsx"

census_clean.to_excel(file_path, index=False)
